# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitamishraz8/machinelearningclasswork/blob/main/ML18_9_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGRESSION PROBLEMS**

# %%
import pandas as pd

# %%
sal = pd.read_csv('/content/drive/MyDrive/age-sal.csv')

# %%
sal.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
# Check for missing values
print(sal.isnull().sum())

# Statistical summary of the dataset
print(sal.describe())

# Check data types
print(sal.dtypes)
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64
#        YearsExperience        Age         Salary
# count        30.000000  30.000000      30.000000
# mean          5.313333  27.216667   76003.000000
# std           2.837888   5.161267   27414.429785
# min           1.100000  21.000000   37731.000000
# 25%           3.200000  23.300000   56720.750000
# 50%           4.700000  25.000000   65237.000000
# 75%           7.700000  30.750000  100544.750000
# max          10.500000  38.000000  122391.000000
# YearsExperience    float64
# Age                float64
# Salary               int64
# dtype: object

# %%
import seaborn as sns
sns.displot(sal['Salary'])
sns.displot(sal['Age'])
sns.displot(sal['YearsExperience'])

# %%
house_data = pd.read_csv('/content/drive/MyDrive/Housing.csv')

# %%
house_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Check for missing values
print(house_data.isnull().sum())

# Statistical summary of the dataset
print(house_data.describe())

# Check data types
print(house_data.dtypes)
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# ...

# %%
iris = pd.read_csv('/content/drive/MyDrive/iris.csv')

# %% [markdown]
# **IRIS PROBLEMS**

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
